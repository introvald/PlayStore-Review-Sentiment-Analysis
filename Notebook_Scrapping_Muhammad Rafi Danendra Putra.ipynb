# %%
# !pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.7-py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 1.6 MB/s eta 0:00:00
# Downloading google_play_scraper-1.2.7-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.7

# %%
from google_play_scraper import reviews, Sort
import csv
print("Mulai scraping BCA mobile...")
scrapreview, _ = reviews(
    'com.bca',
    lang='id',
    country='id',
    sort=Sort.NEWEST,
    count=15000
)

with open('ulasan_aplikasi.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['Review'])

    for review in scrapreview:
        writer.writerow([review['content']])

print("Scraping BCA selesai! File 'ulasan_aplikasi.csv' berhasil dibuat.\n")
# Out:
# Mulai scraping BCA mobile...
# Scraping BCA selesai! File 'ulasan_aplikasi.csv' berhasil dibuat.

# %%
import pandas as pd


app_reviews_df = pd.DataFrame(scrapreview)
app_reviews_df.shape
app_reviews_df.head()
app_reviews_df.to_csv('ulasan_aplikasi.csv', index=False)

# %%
app_reviews_df = pd.DataFrame(scrapreview)
jumlah_ulasan, jumlah_kolom = app_reviews_df.shape

# %%
app_reviews_df.head()
# Out:
#                                reviewId         userName  \
# 0  0321d976-0cc8-4143-9f05-7574651dab78  Pengguna Google
# 1  a292b0aa-418a-400f-89b2-1672154c2d61  Pengguna Google
# 2  3a6844b6-5006-4cb6-9a8a-a90a8de96669  Pengguna Google
# 3  6dfba802-7d06-4830-ab15-40dcec38e467  Pengguna Google
# 4  f5ceab55-2680-429d-825c-29ceb00955d8  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  knp ya akhir" ini Qris BCA susah di akses. loa...      4              0
# 1  kenapa kok sering merah indikator nya , dan it...      1              0
# 2                                    apk nya ngeleg"      1              0
# 3                                   mudah bgt & aman      5              0
# 4                                                 ok      5              0
#
#   reviewCreatedVersion                  at  \
# 0                4.7.9 2026-03-30 05:08:15
# 1                4.7.9 2026-03-30 04:59:48
# 2                 None 2026-03-30 04:50:10
# 3                4.7.9 2026-03-30 04:29:42
# 4                4.7.9 2026-03-30 04:05:55
#
#                                         replyContent           repliedAt  \
# 0  Mohon maaf atas kendala yang Bapak/Ibu alami. ... 2026-03-30 05:25:34
# 1  Mohon maaf atas kendala yang Bapak/Ibu alami. ... 2026-03-30 05:27:50
# 2  Mohon maaf atas kendala yang Bapak/Ibu alami. ... 2026-03-30 05:25:15
# 3  Terima kasih atas ulasannya. Semoga aplikasi B... 2026-03-30 04:32:25
# 4  Terima kasih atas ulasannya. Semoga aplikasi B... 2026-03-30 04:32:22
#
#   appVersion
# 0      4.7.9
# 1      4.7.9
# 2       None
# 3      4.7.9
# 4      4.7.9

# %%
app_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              15000 non-null  object
#  1   userName              15000 non-null  object
#  2   userImage             15000 non-null  object
#  3   content               15000 non-null  object
#  4   score                 15000 non-null  int64
#  5   thumbsUpCount         15000 non-null  int64
#  6   reviewCreatedVersion  11800 non-null  object
#  7   at                    15000 non-null  datetime64[ns]
#  8   replyContent          15000 non-null  object
#  9   repliedAt             15000 non-null  datetime64[ns]
#  10  appVersion            11800 non-null  object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 1.3+ MB

# %%
clean_df = app_reviews_df.dropna()

# %%
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11800 entries, 0 to 14999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              11800 non-null  object
#  1   userName              11800 non-null  object
#  2   userImage             11800 non-null  object
#  3   content               11800 non-null  object
#  4   score                 11800 non-null  int64
#  5   thumbsUpCount         11800 non-null  int64
#  6   reviewCreatedVersion  11800 non-null  object
#  7   at                    11800 non-null  datetime64[ns]
#  8   replyContent          11800 non-null  object
#  9   repliedAt             11800 non-null  datetime64[ns]
#  10  appVersion            11800 non-null  object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 1.1+ MB

# %%
clean_df = clean_df.drop_duplicates()
jumlah_ulasan_setelah_hapus_duplikat, jumlah_kolom_setelah_hapus_duplikat = clean_df.shape
